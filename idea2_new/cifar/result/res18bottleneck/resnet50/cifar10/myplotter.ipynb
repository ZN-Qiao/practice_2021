# %%
import numpy as np
import matplotlib.pyplot as plt

filelist=['0.5.txt','0.6.txt','0.7.txt','0.8.txt','0.9.txt','0.95.txt','1.0.txt']

# for fname in filelist:
#     data=np.loadtxt(fname,skiprows=1)
#     X=data[:,0]
#     Y=data[:,1]
#     plt.plot(X,Y,label= fname.replace('.txt', ''))
# plt.xlabel('#epoch')
# plt.ylabel('loss')
# plt.title('Training loss')
# plt.legend()    
# plt.savefig('Training loss', dpi=500)
# plt.show()

# %%
# for fname in filelist:
#     data=np.loadtxt(fname,skiprows=1)
#     X=data[:,0]
#     Y=data[:,2]
#     plt.plot(X,Y,label= fname.replace('.txt', ''))
# plt.xlabel('#epoch')
# plt.ylabel('loss')
# plt.title('Testing loss')
# plt.legend()    
# plt.savefig('Testing loss', dpi=500)
# plt.show()

# %%
for fname in filelist:
    data=np.loadtxt(fname,skiprows=1)
    X=data[:,0]
    Y=data[:,3]
    plt.plot(X,Y,label= fname.replace('.txt', ''))
plt.xlabel('#epoch')
plt.ylabel('accuracy')
plt.title('Training accuracy')
plt.legend()    
plt.savefig('Training accuracy', dpi=500)
plt.show()

# %%
for fname in filelist:
    data=np.loadtxt(fname,skiprows=1)
    X=data[:,0]
    Y=data[:,4]
    plt.plot(X,Y,label= fname.replace('.txt', ''))
plt.xlabel('#epoch')
plt.ylabel('accuracy')
plt.title('Testing accuracy')
plt.legend()    
plt.savefig('Testing accuracy', dpi=500)
plt.show()

# %%
# for fname in filelist:
#     X=[]
#     Y=[]
# for fname in filelist:
#     data=np.loadtxt(fname,skiprows=1)
#     X.append(float(fname.replace('.txt', '')))
#     Y.append(max(data[:,1]))
# plt.plot(X,Y)
# plt.xlabel('weight')
# plt.ylabel('loss')
# plt.title('Training loss comparison')
# plt.savefig('Training loss comparison', dpi=500)
# plt.show()

# %%
# for fname in filelist:
#     X=[]
#     Y=[]
# for fname in filelist:
#     data=np.loadtxt(fname,skiprows=1)
#     X.append(float(fname.replace('.txt', '')))
#     Y.append(max(data[:,2]))
# plt.plot(X,Y)
# plt.xlabel('weight')
# plt.ylabel('loss')
# plt.title('Testing loss comparison')
# plt.savefig('Testing loss comparison', dpi=500)
# plt.show()

# %%
for fname in filelist:
    X=[]
    Y=[]
for fname in filelist:
    data=np.loadtxt(fname,skiprows=1)
    X.append(float(fname.replace('.txt', '')))
    Y.append(max(data[:,3]))
print(Y)
# plt.plot(X,Y)
# plt.xlabel('weight')
# plt.ylabel('accuracy')
# plt.title('Traning accuracy comparison')
# plt.savefig('Traning accuracy comparison', dpi=500)
# plt.show()
# Out:
# [98.43, 98.92, 98.98, 99.124, 99.216, 99.146, 99.124]

# %%
for fname in filelist:
    X=[]
    Y=[]
for fname in filelist:
    data=np.loadtxt(fname,skiprows=1)
    X.append(float(fname.replace('.txt', '')))
    Y.append(max(data[:,4]))
print(Y)
plt.plot(X,Y)
plt.xlabel('weight')
plt.ylabel('accuracy')
plt.title('Testing accuracy comparison')
plt.savefig('Testing accuracy comparison', dpi=500)
plt.show()
# Out:
# [92.66, 92.87, 92.93, 93.25, 93.17, 92.93, 93.05]
